# %% [markdown]
# <a href="https://colab.research.google.com/github/Onoruoiza514/My-Automation-Project/blob/main/generate_dummy_datas_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-33.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.17.0)
# Downloading Faker-33.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 45.5 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-33.1.0

# %%
from faker import Faker #import faker
import csv #We import csv to create the csv file for our test datas
from google.colab import files #We import files to be able to download the crested file later after creating to our local storage


#Next we initialise faker
fake = Faker()

#Now lets name the csv file
file_name = "recipients.csv"

#Now lets create the csv file
with open(file_name, 'w', newline='', encoding= 'utf-8') as my_file:
    writer = csv.writer(my_file)
    #Lets write the hewder row(the names of the columms precisely)
    writer.writerow(['Name', 'Email', 'Subject', 'Message', 'Address'])


    #Now lets generate about 50 rows dummy datas,since we are just going to he testing
    for yo in range(50):
        name = fake.name()
        email = fake.email()
        address = fake.address()
        subject = "Welcome to our test service,sorry for any inconveniences experienced"
        message = f"Hello {name}, we are excited to have you onboard,this is to confirm that {address} is your valid home address, if its noe kindly get back to is as soon as possible "
        #address= fake.address_detail()
        writer.writerow([name , email , subject , message , address])

print(f"dummy values has been created successfully in {file_name}")

#Now lets download our csv file
files.download(file_name)

import pandas as pd
df = pd.read_csv(file_name)
df.head(50)
# Out:
# dummy values has been created successfully in recipients.csv
#                    Name                         Email  \
# 0         Anthony Lopez           james13@example.org
# 1           David Smith          ohoffman@example.org
# 2          Emily Graham           megan54@example.org
# 3           Kyle Massey         keithcarr@example.org
# 4           Bruce Keith   robertscharlene@example.com
# 5       Rebecca Mccarty         johnwyatt@example.net
# 6        Matthew Meyers           david97@example.net
# 7       Matthew Gilbert    williskimberly@example.org
# 8    William Washington           edwin84@example.net
# 9          James Barron     michellelewis@example.com
# 10         Susan Taylor            john18@example.net
# 11      Rebecca Mahoney       chapmanmary@example.net
# 12        Taylor Adkins          zcoleman@example.net
# 13         Brenda Jones           casey30@example.com
# 14         James Weaver           mchavez@example.net
# 15       Jennifer Henry  jacquelinelarsen@example.org
# 16       Shannon Taylor     heatherlester@example.net
# 17       Christina Bond    reginagallegos@example.com
# 18   Jacqueline Buckley   salazarpatricia@example.net
# 19     Cynthia Gonzales     albertsanders@example.com
# 20          Lori Glover           brian04@example.org
# 21       Bryan Williams            chad14@example.com
# 22       Jennifer Clark        smithtammy@example.net
# 23       Amy Richardson         nfletcher@example.com
# 24           Walter Key            tsmith@example.com
# 25         Bryan Thomas             sdyer@example.net
# 26          Shawn Glenn      allenphillip@example.com
# 27         Colton Bowen           btorres@example.net
# 28         Jill Osborne   patriciaelliott@example.net
# 2       6769 Moore Knoll Apt. 025\nJoeshire, DE 98602
# 3   3106 Blankenship Plains Apt. 682\nNorth Evan, ...
# 4           18875 Christine Mill\nYoungport, PR 86759
# 5             1147 Scott Meadow\nHolmesfort, NM 60559
# 6   62075 Brandon Run Suite 336\nNorth Rodneyburgh...
# 7      9198 Williams Estate\nPort Elizabeth, WA 65855
# 8      4051 Crawford Station\nLake Danaside, CO 11440
# 9            7499 Wolf Drive\nEast Adrienne, IN 64158
# 10            0999 Griffin Locks\nSmithfort, FM 02921
# 11  3886 Tiffany Fords Suite 577\nNorth James, GU ...
# 12  03596 Margaret Bridge Suite 755\nHeathercheste...
# 13                   PSC 7770, Box 4860\nAPO AE 43566
# 14    576 Norris Square\nSouth Michaelburgh, WY 23272
# 15                   Unit 2952 Box 3333\nDPO AP 76056
# 16  3051 Irwin Station Apt. 866\nAyalamouth, MS 37944
# 17  5478 David Corner Suite 341\nEast Loriland, NM...
# 18               459 Michele Loop\nBellberg, OR 97524
# 19  51122 Jones Motorway Suite 050\nPort David, CT...
# 20             5118 Joseph Gateway\nAmybury, LA 02318
# 21  254 King Burgs Apt. 456\nPort Edwardstad, CA 7...
# 22  5625 Lopez Path Apt. 995\nNorth Charleschester...
# 23    3941 Herman Parks Suite 057\nOwenside, WI 40475
# 24  1572 Stark Harbor Apt. 368\nNorth Jasonfort, M...
# 25  63047 Ramirez Glen Apt. 604\nAlvarezburgh, MO ...
# 26              502 Baker Route\nTylerville, NY 07599
# 27  895 Walsh Road Suite 923\nSouth Michaelmouth, ...
# 28            98825 Caitlin Glen\nPort Mary, WI 75594
# 29   580 Laura Crest Apt. 646\nJohnsonshire, AL 69335
# 30  1285 Campbell Vista Suite 828\nMurrayside, ND ...
# 31               390 Jake Spur\nSouth Stacy, NC 34248
# 32   864 William Lodge Suite 847\nKevinport, NH 01857
# 33    446 Burch Vista Apt. 203\nCrystalport, KY 72037
# 34  042 Jennifer Path Suite 087\nNorth Kimberlysta...
# 35                   Unit 4344 Box 1460\nDPO AE 73290
# 36  600 Kevin Prairie Suite 947\nRebeccachester, T...
# 37  29751 Alexander Ports Suite 176\nBradburgh, NV...
# 38      64538 Donald Port Apt. 398\nLeeview, NV 54659
# 39  5601 Johnson Overpass Suite 859\nNew Lisa, TN ...
# 40          2010 Lynch Prairie\nTravismouth, TX 96573
# 41      641 Megan Haven Apt. 763\nChrisfort, PA 41580
# 42              993 Leslie Mews\nKellymouth, TN 68175
# 43  33539 Matthew Creek Apt. 781\nAngelastad, FM 3...
# 44           4593 Jennifer Rest\nAnitamouth, TX 86626
# 45                189 Samuel Isle\nBoydfurt, PA 90183
# 46  8401 Jessica Village Apt. 413\nPort Steveside,...
# 47         8120 Mcmillan Key\nWest Omarview, TN 67231
# 48      9803 Kevin Meadows\nWest Danielfort, MT 42780
# 49  13263 Rachel Lakes Suite 358\nWest Jimview, RI...
